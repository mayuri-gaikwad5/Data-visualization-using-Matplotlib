# %% [markdown]
# # Functions

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,4]
plt.plot(x,y)
plt.xlim(0,10) # limit function
plt.ylim(0,10)
plt.show()
# graph shrinks

# %%
x=[1,2,3,4]
y=[3,1,5,2]
plt.plot(x,y)

plt.xticks(x,labels=['python','c','c++','java'])
plt.yticks(y)

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,4]
plt.plot(x,y)
plt.axis([0,10,0,7]) # x axis is 0-10 and y axis is 0-7
plt.show()

# %% [markdown]
# # Working with text in Matplotlib Python

# %% [markdown]
# - text :- add text at an arbitrary location of the Axes
# - annotate :- Add an annotation , with an optional arrow, at an arbitrary location of the Axes.
# - xlabel:- Add a label to the Axes's x-axis
# - ylabel:- Add a label to the Axes's y-axis
# - title:- Add a title to the Axes

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)
plt.title('Python Growth',fontsize=20)
plt.xlabel('Days',fontsize=15)
plt.ylabel('Python',fontsize=15)

plt.text(2,5,'java',fontsize=15,style='italic',bbox={'facecolor':'red'})


plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)
plt.title('Python Growth',fontsize=20)
plt.xlabel('Days',fontsize=15)
plt.ylabel('Python',fontsize=15)

plt.text(2,5,'java',fontsize=15,style='italic',bbox={'facecolor':'red'})
# annotate function
plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor='black',shrink=100))

plt.show()

# %%
x=[1,2,3,4,5]
y=[3,1,5,2,6]

plt.plot(x,y)
plt.title('Python Growth',fontsize=20)
plt.xlabel('Days',fontsize=15)
plt.ylabel('Python',fontsize=15)


plt.legend(['up'],loc=9,facecolor='yellow',
          edgecolor='red',framealpha=0.5,
          shadow=True)


plt.show()
